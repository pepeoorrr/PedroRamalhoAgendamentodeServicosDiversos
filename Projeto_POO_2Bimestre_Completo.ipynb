# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**    Pedro Ramalho
#
# **Turma:** 2B t.i
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class AgendamentoServico:
    # Definindo o construtor com 3 atributos principais
    def __init__(self, nome_cliente, tipo_servico, data_agendamento):
        self.nome_cliente = nome_cliente      # Nome do cliente
        self.tipo_servico = tipo_servico      # Tipo de serviço agendado
        self.data_agendamento = data_agendamento  # Data do agendamento

    # Método para exibir os dados do agendamento
    def exibir_dados(self):
        print(f"Cliente: {self.nome_cliente}")
        print(f"Serviço Agendado: {self.tipo_servico}")
        print(f"Data do Agendamento: {self.data_agendamento}")
        print("-" * 30)

# Criando objetos (instâncias) da classe AgendamentoServico
agendamento1 = AgendamentoServico("Maria Silva", "Corte de Cabelo", "2025-05-10")
agendamento2 = AgendamentoServico("João Oliveira", "Limpeza de Pele", "2025-05-12")

# Exibindo os dados dos agendamentos
agendamento1.exibir_dados()
agendamento2.exibir_dados()
# Out:
# Cliente: Maria Silva
# Serviço Agendado: Corte de Cabelo
# Data do Agendamento: 2025-05-10
# ------------------------------
# Cliente: João Oliveira
# Serviço Agendado: Limpeza de Pele
# Data do Agendamento: 2025-05-12
# ------------------------------

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class AgendamentoServico:
    def __init__(self, nome_cliente, tipo_servico, data_agendamento):
        self.nome_cliente = nome_cliente
        self.tipo_servico = tipo_servico
        self.data_agendamento = data_agendamento
        self.status = "Agendado"

    def exibir_dados(self):
        print(f"Cliente: {self.nome_cliente}")
        print(f"Serviço Agendado: {self.tipo_servico}")
        print(f"Data do Agendamento: {self.data_agendamento}")
        print(f"Status: {self.status}")
        print("-" * 30)

    # Método de ação 1
    def remarcar(self, nova_data):
        self.data_agendamento = nova_data
        print(f"Agendamento de {self.nome_cliente} foi remarcado para {self.data_agendamento}.")

    # Método de ação 2
    def cancelar(self):
        self.status = "Cancelado"
        print(f"Agendamento de {self.nome_cliente} foi cancelado.")

# Subclasse com herança
class AgendamentoServicoResidencial(AgendamentoServico):
    def __init__(self, nome_cliente, tipo_servico, data_agendamento, endereco):
        super().__init__(nome_cliente, tipo_servico, data_agendamento)
        self.endereco = endereco  # Novo atributo

    # Novo método exclusivo da subclasse
    def confirmar_endereco(self):
        print(f"Serviço residencial será realizado no endereço: {self.endereco}")

# Testes
agendamento1 = AgendamentoServico("Carlos Souza", "Manutenção de Ar", "2025-06-01")
agendamento1.exibir_dados()
agendamento1.remarcar("2025-06-10")

agendamento2 = AgendamentoServicoResidencial("Luciana Alves", "Dedetização", "2025-06-03", "Av. Central, 456")
agendamento2.exibir_dados()
agendamento2.confirmar_endereco()
# Out:
# Cliente: Carlos Souza
# Serviço Agendado: Manutenção de Ar
# Data do Agendamento: 2025-06-01
# Status: Agendado
# ------------------------------
# Agendamento de Carlos Souza foi remarcado para 2025-06-10.
# Cliente: Luciana Alves
# Serviço Agendado: Dedetização
# Data do Agendamento: 2025-06-03
# Status: Agendado
# ------------------------------
# Serviço residencial será realizado no endereço: Av. Central, 456

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class AgendamentoServico:
    def __init__(self, nome_cliente, tipo_servico, data_agendamento):
        self.__nome_cliente = nome_cliente  # Atributo privado
        self.tipo_servico = tipo_servico
        self.data_agendamento = data_agendamento
        self.status = "Agendado"

    # Getter
    def get_nome_cliente(self):
        return self.__nome_cliente

    # Setter
    def set_nome_cliente(self, novo_nome):
        if novo_nome.strip() != "":
            self.__nome_cliente = novo_nome
        else:
            print("Nome inválido!")

    def exibir_dados(self):
        print(f"Cliente: {self.__nome_cliente}")
        print(f"Serviço Agendado: {self.tipo_servico}")
        print(f"Data do Agendamento: {self.data_agendamento}")
        print(f"Status: {self.status}")
        print("-" * 30)

    def remarcar(self, nova_data):
        self.data_agendamento = nova_data
        print(f"Agendamento de {self.__nome_cliente} foi remarcado para {self.data_agendamento}.")

    def cancelar(self):
        self.status = "Cancelado"
        print(f"Agendamento de {self.__nome_cliente} foi cancelado.")

    # Método com lógica interna (abstração)
    def verificar_agendamento(self):
        if self.status == "Cancelado":
            print(f"Agendamento de {self.__nome_cliente} está cancelado.")
        else:
            print(f"Agendamento de {self.__nome_cliente} está ativo para {self.data_agendamento}.")

# Subclasse com herança
class AgendamentoServicoResidencial(AgendamentoServico):
    def __init__(self, nome_cliente, tipo_servico, data_agendamento, endereco):
        super().__init__(nome_cliente, tipo_servico, data_agendamento)
        self.endereco = endereco

    def confirmar_endereco(self):
        print(f"Serviço residencial será realizado no endereço: {self.endereco}")

# Testes com encapsulamento e lógica interna
agendamento = AgendamentoServico("Ana Clara", "Limpeza", "2025-06-15")
agendamento.exibir_dados()
agendamento.verificar_agendamento()
agendamento.cancelar()
agendamento.verificar_agendamento()

# Teste dos métodos get e set
print("Nome atual:", agendamento.get_nome_cliente())
agendamento.set_nome_cliente("Ana Clara Silva")
print("Nome atualizado:", agendamento.get_nome_cliente())
# Out:
# Cliente: Ana Clara
# Serviço Agendado: Limpeza
# Data do Agendamento: 2025-06-15
# Status: Agendado
# ------------------------------
# Agendamento de Ana Clara está ativo para 2025-06-15.
# Agendamento de Ana Clara foi cancelado.
# Agendamento de Ana Clara está cancelado.
# Nome atual: Ana Clara
# Nome atualizado: Ana Clara Silva

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

# Classe principal
class AgendamentoServico:
    def __init__(self, nome_cliente, tipo_servico, data_agendamento):
        self.__nome_cliente = nome_cliente
        self.tipo_servico = tipo_servico
        self.data_agendamento = data_agendamento
        self.status = "Agendado"

    def get_nome_cliente(self):
        return self.__nome_cliente

    def set_nome_cliente(self, novo_nome):
        if novo_nome.strip() != "":
            self.__nome_cliente = novo_nome
        else:
            print("Nome inválido!")

    def exibir_dados(self):
        print(f"Cliente: {self.__nome_cliente}")
        print(f"Serviço Agendado: {self.tipo_servico}")
        print(f"Data do Agendamento: {self.data_agendamento}")
        print(f"Status: {self.status}")
        print("-" * 30)

# Subclasse com polimorfismo (sobrescrevendo exibir_dados)
class AgendamentoServicoResidencial(AgendamentoServico):
    def __init__(self, nome_cliente, tipo_servico, data_agendamento, endereco):
        super().__init__(nome_cliente, tipo_servico, data_agendamento)
        self.endereco = endereco

    # Polimorfismo: sobrescrevendo o método da classe pai
    def exibir_dados(self):
        super().exibir_dados()
        print(f"Endereço do Serviço: {self.endereco}")
        print("-" * 30)

# ------------------------
# Integração com SQLite
# ------------------------

# Conectando ao banco
conexao = sqlite3.connect("agendamentos.db")
cursor = conexao.cursor()

# Criando a tabela (caso não exista)
cursor.execute("""
CREATE TABLE IF NOT EXISTS agendamentos (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome_cliente TEXT,
    tipo_servico TEXT,
    data_agendamento TEXT,
    endereco TEXT
)
""")
conexao.commit()

# Função para inserir agendamento
def inserir_agendamento(nome, tipo, data, endereco=None):
    cursor.execute("INSERT INTO agendamentos (nome_cliente, tipo_servico, data_agendamento, endereco) VALUES (?, ?, ?, ?)", 
                   (nome, tipo, data, endereco))
    conexao.commit()
    print("Agendamento inserido com sucesso.")

# Função para consultar todos os agendamentos
def consultar_agendamentos():
    cursor.execute("SELECT * FROM agendamentos")
    resultados = cursor.fetchall()
    print("=== Agendamentos no banco ===")
    for linha in resultados:
        print(linha)
    print("-" * 30)

# Função para deletar agendamento por ID
def deletar_agendamento(id_agendamento):
    cursor.execute("DELETE FROM agendamentos WHERE id = ?", (id_agendamento,))
    conexao.commit()
    print(f"Agendamento com ID {id_agendamento} foi excluído.")

# -----------------------
# Testando o banco
# -----------------------
inserir_agendamento("Ana Clara", "Limpeza", "2025-06-15", "Rua das Flores, 123")
inserir_agendamento("Carlos Souza", "Manutenção de Ar", "2025-06-10")

consultar_agendamentos()

deletar_agendamento(1)  # Excluindo o ID 1 como exemplo
consultar_agendamentos()

# Encerrando conexão
conexao.close()
# Out:
# Agendamento inserido com sucesso.
# Agendamento inserido com sucesso.
# === Agendamentos no banco ===
# (2, 'Carlos Souza', 'Manutenção de Ar', '2025-06-10', None)
# (3, 'Gustavo', 'Jardinagem', '2025-06-07', 'rua aurora')
# (4, '', '', '', None)
# (5, 'Ana Clara', 'Limpeza', '2025-06-15', 'Rua das Flores, 123')
# (6, 'Carlos Souza', 'Manutenção de Ar', '2025-06-10', None)
# ------------------------------
# Agendamento com ID 1 foi excluído.
# === Agendamentos no banco ===
# (2, 'Carlos Souza', 'Manutenção de Ar', '2025-06-10', None)
# (3, 'Gustavo', 'Jardinagem', '2025-06-07', 'rua aurora')
# (4, '', '', '', None)
# (5, 'Ana Clara', 'Limpeza', '2025-06-15', 'Rua das Flores, 123')
# (6, 'Carlos Souza', 'Manutenção de Ar', '2025-06-10', None)
# ------------------------------

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# -------------------------
# Classe base com encapsulamento
# -------------------------
class AgendamentoServico:
    def __init__(self, nome_cliente, tipo_servico, data_agendamento):
        self.__nome_cliente = nome_cliente
        self.tipo_servico = tipo_servico
        self.data_agendamento = data_agendamento
        self.status = "Agendado"

    def get_nome_cliente(self):
        return self.__nome_cliente

    def set_nome_cliente(self, novo_nome):
        if novo_nome.strip() != "":
            self.__nome_cliente = novo_nome
        else:
            print("Nome inválido!")

    def remarcar(self, nova_data):
        self.data_agendamento = nova_data

    def cancelar(self):
        self.status = "Cancelado"

    def verificar_agendamento(self):
        if self.status == "Cancelado":
            print(f"Agendamento de {self.__nome_cliente} está cancelado.")
        else:
            print(f"Agendamento de {self.__nome_cliente} está ativo.")

    def exibir_dados(self):
        print(f"Cliente: {self.__nome_cliente}")
        print(f"Serviço: {self.tipo_servico}")
        print(f"Data: {self.data_agendamento}")
        print(f"Status: {self.status}")
        print("-" * 30)

class AgendamentoServicoResidencial(AgendamentoServico):
    def __init__(self, nome_cliente, tipo_servico, data_agendamento, endereco):
        super().__init__(nome_cliente, tipo_servico, data_agendamento)
        self.endereco = endereco

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Endereço do Serviço: {self.endereco}")
        print("-" * 30)

# -------------------------
# Banco de dados (SQLite)
# -------------------------
conexao = sqlite3.connect("agendamentos.db")
cursor = conexao.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS agendamentos (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    nome_cliente TEXT,
    tipo_servico TEXT,
    data_agendamento TEXT,
    endereco TEXT
)
""")
conexao.commit()

def inserir_agendamento(nome, tipo, data, endereco=None):
    cursor.execute("INSERT INTO agendamentos (nome_cliente, tipo_servico, data_agendamento, endereco) VALUES (?, ?, ?, ?)",
                   (nome, tipo, data, endereco))
    conexao.commit()

def consultar_agendamentos():
    cursor.execute("SELECT * FROM agendamentos")
    agendamentos = cursor.fetchall()
    for ag in agendamentos:
        print(f"ID: {ag[0]} | Cliente: {ag[1]} | Serviço: {ag[2]} | Data: {ag[3]} | Endereço: {ag[4]}")
    return agendamentos

def deletar_agendamento(id_agendamento):
    cursor.execute("DELETE FROM agendamentos WHERE id = ?", (id_agendamento,))
    conexao.commit()

def remarcar_agendamento(id_agendamento, nova_data):
    cursor.execute("UPDATE agendamentos SET data_agendamento = ? WHERE id = ?", (nova_data, id_agendamento))
    conexao.commit()

def editar_nome_cliente(id_agendamento, novo_nome):
    cursor.execute("UPDATE agendamentos SET nome_cliente = ? WHERE id = ?", (novo_nome, id_agendamento))
    conexao.commit()

# -------------------------
# Menu Interativo
# -------------------------
def menu():
    while True:
        print("\n==== MENU DE AGENDAMENTOS ====")
        print("1. Cadastrar Agendamento")
        print("2. Listar Agendamentos")
        print("3. Editar Nome do Cliente")
        print("4. Remarcar Agendamento")
        print("5. Cancelar/Excluir Agendamento")
        print("0. Sair")
        escolha = input("Escolha uma opção: ")

        if escolha == "1":
            nome = input("Nome do Cliente: ")
            tipo = input("Tipo de Serviço: ")
            data = input("Data do Agendamento (AAAA-MM-DD): ")
            residencial = input("Serviço Residencial? (s/n): ").lower()
            if residencial == "s":
                endereco = input("Endereço do Serviço: ")
                inserir_agendamento(nome, tipo, data, endereco)
            else:
                inserir_agendamento(nome, tipo, data)
            print("✅ Agendamento inserido com sucesso.")

        elif escolha == "2":
            print("\n--- Lista de Agendamentos ---")
            consultar_agendamentos()

        elif escolha == "3":
            consultar_agendamentos()
            id_editar = input("Digite o ID do agendamento para editar: ")
            novo_nome = input("Novo nome do cliente: ")
            editar_nome_cliente(id_editar, novo_nome)
            print("✅ Nome atualizado.")

        elif escolha == "4":
            consultar_agendamentos()
            id_remarcar = input("Digite o ID do agendamento para remarcar: ")
            nova_data = input("Nova data (AAAA-MM-DD): ")
            remarcar_agendamento(id_remarcar, nova_data)
            print("✅ Agendamento remarcado.")

        elif escolha == "5":
            consultar_agendamentos()
            id_excluir = input("Digite o ID do agendamento para excluir: ")
            deletar_agendamento(id_excluir)
            print("✅ Agendamento cancelado/excluído.")

        elif escolha == "0":
            print("Encerrando o sistema...")
            break

        else:
            print("❌ Opção inválida! Tente novamente.")

# -------------------------
# Execução do Menu
# -------------------------
menu()
conexao.close()
# Out:
# ==== MENU DE AGENDAMENTOS ====
# 1. Cadastrar Agendamento
# 2. Listar Agendamentos
# 3. Editar Nome do Cliente
# 4. Remarcar Agendamento
# 5. Cancelar/Excluir Agendamento
# 0. Sair
# ✅ Agendamento inserido com sucesso.
#
# ==== MENU DE AGENDAMENTOS ====
# 1. Cadastrar Agendamento
# 2. Listar Agendamentos
# 3. Editar Nome do Cliente
# 4. Remarcar Agendamento
# 5. Cancelar/Excluir Agendamento
# 0. Sair
#
# --- Lista de Agendamentos ---
# ID: 2 | Cliente: Carlos Souza | Serviço: Manutenção de Ar | Data: 2025-06-10 | Endereço: None
# ID: 3 | Cliente: Gustavo | Serviço: Jardinagem | Data: 2025-06-07 | Endereço: rua aurora
# ID: 4 | Cliente:  | Serviço:  | Data:  | Endereço: None
# ID: 5 | Cliente: Ana Clara | Serviço: Limpeza | Data: 2025-06-15 | Endereço: Rua das Flores, 123
# ID: 6 | Cliente: Carlos Souza | Serviço: Manutenção de Ar | Data: 2025-06-10 | Endereço: None
# ID: 7 | Cliente: Gustavo | Serviço: Jardinagem | Data: 2022-01-09 | Endereço: None
#
# ==== MENU DE AGENDAMENTOS ====
# ...
